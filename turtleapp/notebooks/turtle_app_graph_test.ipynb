# %% [markdown]
# # Turtle App Graph Testing Notebook
#
# Simple Jupyter notebook for testing the multi-agent workflow graph with basic queries and result inspection.

# %% [markdown]
# ## 1. Basic Setup and Imports

# %%
# Complete imports for turtle app testing (from turtleapp/notebooks/)
import sys
import os

# Add the project root to Python path for proper imports
project_root = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('__file__' if '__file__' in locals() else '.'))))
sys.path.insert(0, project_root)

from turtleapp.src.workflows.graph import movie_workflow_agent
from turtleapp.src.core.tools import movie_retriever_tool, library_manager_tool
from turtleapp.src.core.tools.torrent_tools import torrent_search_tool, torrent_download_tool
import time
from datetime import datetime

# Verify setup with comprehensive error handling
print("🔄 Initializing Turtle App Graph Testing Environment...")
print(f"📁 Project root: {project_root}")
print(f"⏰ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print()

try:
    # Test basic graph functionality with timing
    start_time = time.time()
    test_result, test_thread = movie_workflow_agent.invoke("test")
    setup_time = time.time() - start_time
    
    print("✅ Graph loaded and functional")
    print(f"✅ Thread management working (Thread ID: {test_thread})")
    print(f"✅ Setup completed in {setup_time:.2f} seconds")
    print()
    
    # Test individual tools
    print("🔧 Testing individual tools...")
    try:
        movie_retriever_tool._run("test query")
        print("✅ Movie retriever tool: Ready")
    except Exception as e:
        print(f"⚠️  Movie retriever tool: {str(e)[:50]}...")
    
    try:
        library_manager_tool._run("test")
        print("✅ Library manager tool: Ready")
    except Exception as e:
        print(f"⚠️  Library manager tool: {str(e)[:50]}...")
    
    try:
        torrent_search_tool._run("test")
        print("✅ Torrent search tool: Ready")
    except Exception as e:
        print(f"⚠️  Torrent search tool: {str(e)[:50]}...")
    
    try:
        torrent_download_tool._run("test")
        print("✅ Torrent download tool: Ready")
    except Exception as e:
        print(f"⚠️  Torrent download tool: {str(e)[:50]}...")
        
except Exception as e:
    print(f"❌ Setup issue: {e}")
    print("Please check your environment setup and dependencies:")
    print("  - Ensure all API keys are set in your .env file")
    print("  - Verify external services (Pinecone, OpenAI, qBittorrent) are accessible")
    print("  - Check network connectivity for SMB shares")

print()
print("✅ All imports loaded successfully")
print("🚀 Ready for testing!")
# Out:
# 2025-07-30 20:57:52,502 - supervisor.py:18 - INFO - Initializing SupervisorNodeCreator with members: ['movie_details_retriever_agent', 'movies_download_manager', 'library_manager_agent']
# 2025-07-30 20:57:52,671 - supervisor.py:21 - INFO - Supervisor processing request
# 🔄 Initializing Turtle App Graph Testing Environment...
# 📁 Project root: /Users/elisar.chodorov/git
# ⏰ Started at: 2025-07-30 20:57:52
# 2025-07-30 20:57:53,927 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:57:53,955 - supervisor.py:32 - INFO - Supervisor routing to END
# ✅ Graph loaded and functional
# ✅ Thread management working (Thread ID: 20250730_205752_76f88244)
# ✅ Setup completed in 1.45 seconds
#
# 🔧 Testing individual tools...
# 2025-07-30 20:57:55,037 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 20:57:56,325 - connection.py:741 - INFO - Initialising connection, guid: c879ba12-80eb-4e85-93f2-247dab349547, require_signing: True, server_name: 192.168.1.205, port: 445
# 2025-07-30 20:57:56,326 - connection.py:867 - INFO - Setting up transport connection
# 2025-07-30 20:57:56,327 - transport.py:64 - INFO - Connecting to DirectTcp socket
# 2025-07-30 20:57:56,342 - connection.py:876 - INFO - Starting negotiation with SMB server
# 2025-07-30 20:57:56,343 - connection.py:1546 - INFO - Negotiating with SMB2 protocol with highest client dialect of: SMB_3_1_1
# 2025-07-30 20:57:56,344 - connection.py:1610 - INFO - Sending SMB2 Negotiate message
# 2025-07-30 20:57:56,353 - connection.py:1615 - INFO - Receiving SMB2 Negotiate response
# 2025-07-30 20:57:56,354 - connection.py:889 - INFO - Negotiated dialect: (785) SMB_3_1_1
# 2025-07-30 20:57:56,355 - connection.py:901 - INFO - Connection require signing: True
# 2025-07-30 20:57:56,356 - session.py:226 - INFO - Initialising session with username: dave
# 2025-07-30 20:57:56,360 - session.py:302 - INFO - Sending SMB2_SESSION_SETUP request message
# 2025-07-30 20:57:56,361 - session.py:306 - INFO - Receiving SMB2_SESSION_SETUP response message
# 2025-07-30 20:57:56,364 - session.py:328 - INFO - More processing is required for SMB2_SESSION_SETUP
# 2025-07-30 20:57:56,383 - session.py:302 - INFO - Sending SMB2_SESSION_SETUP request message
# 2025-07-30 20:57:56,384 - session.py:306 - INFO - Receiving SMB2_SESSION_SETUP response message
# 2025-07-30 20:57:56,388 - session.py:330 - INFO - Setting session id to 1283268432
# 2025-07-30 20:57:56,391 - session.py:402 - INFO - Verifying the SMB Setup Session signature as auth is successful
# 2025-07-30 20:57:56,392 - tree.py:238 - INFO - Session: dave - Creating connection to share \\192.168.1.205\daves
# 2025-07-30 20:57:56,393 - tree.py:243 - INFO - Session: dave - Sending Tree Connect message
# 2025-07-30 20:57:56,394 - tree.py:247 - INFO - Session: dave - Receiving Tree Connect response
# 2025-07-30 20:57:56,398 - tree.py:255 - INFO - Session: dave - Created tree connection with ID 3881477993
# 2025-07-30 20:57:56,399 - tree.py:296 - INFO - Session: dave, Tree: \\192.168.1.205\daves - Running secure negotiate process
# 2025-07-30 20:57:56,401 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,405 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:57:56,406 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,411 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:57:56,412 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,414 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:57:56,415 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,419 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,426 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,428 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,431 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:57:56,434 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,439 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:57:56,440 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,444 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:57:56,445 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,448 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,455 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,457 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,466 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:57:56,468 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,472 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:57:56,474 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,476 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:57:56,477 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,482 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,489 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,493 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:57:56,499 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:57:56,500 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,504 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:57:56,506 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:57:56,508 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:57:56,509 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:57:56,512 - library_manager.py:30 - INFO - Found 2 movies in library
# ✅ Movie retriever tool: Ready
# ✅ Library manager tool: Ready
# 2025-07-30 20:58:01,538 - error_handler.py:62 - ERROR - TorrentAPI error in api_call: 400 Client Error: Bad Request for url: http://192.168.1.205:15080/api/v2/search/results
# 2025-07-30 20:58:01,539 - error_handler.py:62 - ERROR - TorrentAPI error in search_torrents: 'NoneType' object has no attribute 'status_code'
# ✅ Torrent search tool: Ready
# ✅ Torrent download tool: Ready
#
# ✅ All imports loaded successfully
# 🚀 Ready for testing!

# %%
import psutil
import os
from collections import defaultdict

class PerformanceMonitor:
    """Monitor performance metrics for graph operations"""
    
    def __init__(self):
        self.metrics = defaultdict(list)
        self.process = psutil.Process(os.getpid())
    
    def benchmark_query(self, query, thread_id=None, iterations=1):
        """Benchmark a query with performance metrics"""
        print(f"📊 Benchmarking: '{query}' ({iterations} iteration(s))")
        print("-" * 50)
        
        total_time = 0
        memory_usage = []
        
        for i in range(iterations):
            # Memory before
            memory_before = self.process.memory_info().rss / 1024 / 1024  # MB
            
            # Time the operation
            start_time = time.time()
            result, returned_thread_id = movie_workflow_agent.invoke(query, thread_id)
            execution_time = time.time() - start_time
            
            # Memory after
            memory_after = self.process.memory_info().rss / 1024 / 1024  # MB
            memory_delta = memory_after - memory_before
            
            total_time += execution_time
            memory_usage.append(memory_delta)
            
            if iterations > 1:
                print(f"  Iteration {i+1}: {execution_time:.2f}s, Memory: +{memory_delta:.1f}MB")
        
        # Summary statistics
        avg_time = total_time / iterations
        avg_memory = sum(memory_usage) / len(memory_usage)
        
        print(f"📈 Results:")
        print(f"  Average time: {avg_time:.2f}s")
        print(f"  Total time: {total_time:.2f}s")
        print(f"  Average memory delta: {avg_memory:.1f}MB")
        print(f"  Current memory usage: {self.process.memory_info().rss / 1024 / 1024:.1f}MB")
        
        # Store metrics
        self.metrics['execution_times'].append(avg_time)
        self.metrics['memory_deltas'].append(avg_memory)
        
        return result, returned_thread_id
    
    def analyze_routing_performance(self, test_queries):
        """Analyze agent routing performance across multiple queries"""
        print("🎯 Analyzing Agent Routing Performance")
        print("=" * 50)
        
        routing_times = {}
        
        for query in test_queries:
            print(f"Testing: {query}")
            start_time = time.time()
            
            try:
                result, _ = movie_workflow_agent.invoke(query)
                routing_time = time.time() - start_time
                
                # Determine which agent was used (simplified analysis)
                agent_used = "supervisor"  # Default
                if result and 'messages' in result:
                    for msg in result['messages']:
                        if hasattr(msg, 'name') and msg.name:
                            agent_used = msg.name
                            break
                
                if agent_used not in routing_times:
                    routing_times[agent_used] = []
                routing_times[agent_used].append(routing_time)
                
                print(f"  → {agent_used}: {routing_time:.2f}s")
                
            except Exception as e:
                print(f"  → Error: {e}")
        
        print(f"\n📊 Routing Performance Summary:")
        for agent, times in routing_times.items():
            avg_time = sum(times) / len(times)
            print(f"  {agent}: {avg_time:.2f}s avg ({len(times)} queries)")
    
    def get_system_info(self):
        """Get current system performance info"""
        cpu_percent = psutil.cpu_percent(interval=1)
        memory = psutil.virtual_memory()
        
        print("💻 System Performance Info:")
        print(f"  CPU Usage: {cpu_percent}%")
        print(f"  Memory Usage: {memory.percent}% ({memory.used / 1024 / 1024 / 1024:.1f}GB / {memory.total / 1024 / 1024 / 1024:.1f}GB)")
        print(f"  Process Memory: {self.process.memory_info().rss / 1024 / 1024:.1f}MB")

# Create performance monitor instance
perf_monitor = PerformanceMonitor()

# Show current system info
perf_monitor.get_system_info()
# Out:
# 💻 System Performance Info:
#   CPU Usage: 79.9%
#   Memory Usage: 95.7% (1.6GB / 18.0GB)
#   Process Memory: 156.1MB

# %% [markdown]
# ## Performance Monitoring Helpers
#
# Tools for measuring execution time, memory usage, and analyzing agent routing performance.

# %%
# Enhanced error handling for graph operations
def safe_invoke(query, thread_id=None, timeout=30):
    """
    Safely invoke the movie workflow with comprehensive error handling
    """
    print(f"🔄 Processing: '{query}'")
    start_time = time.time()
    
    try:
        result, returned_thread_id = movie_workflow_agent.invoke(query, thread_id)
        execution_time = time.time() - start_time
        
        if result and 'messages' in result and result['messages']:
            response = result['messages'][-1].content
            print(f"✅ Success ({execution_time:.2f}s): {response[:100]}...")
            return result, returned_thread_id
        else:
            print("⚠️  Warning: Empty response received")
            return None, returned_thread_id
            
    except ConnectionError as e:
        print(f"🌐 Network Error: {e}")
        print("   → Check your internet connection and API endpoints")
        return None, thread_id
        
    except TimeoutError as e:
        print(f"⏱️  Timeout Error: {e}")
        print("   → Query took too long, try a simpler request")
        return None, thread_id
        
    except KeyError as e:
        print(f"🔑 Configuration Error: {e}")
        print("   → Check your API keys and environment variables")
        return None, thread_id
        
    except Exception as e:
        execution_time = time.time() - start_time
        print(f"❌ Unexpected Error ({execution_time:.2f}s): {type(e).__name__}: {e}")
        print("   → Check logs for detailed error information")
        return None, thread_id

# Test the enhanced error handling
test_result, test_thread = safe_invoke("What movies are in my library?")
# Out:
# 2025-07-30 20:58:08,607 - supervisor.py:21 - INFO - Supervisor processing request
# 🔄 Processing: 'What movies are in my library?'
# 2025-07-30 20:58:10,557 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:10,562 - supervisor.py:34 - INFO - Supervisor routing to: library_manager_agent
# 2025-07-30 20:58:10,565 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,569 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:10,570 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,575 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:10,583 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,586 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:58:10,586 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,591 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,599 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,601 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,604 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:10,607 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,611 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:10,612 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,615 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:10,616 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,621 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,626 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,627 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,631 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:10,632 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,637 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:10,638 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,640 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:10,641 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,647 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,653 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,655 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:10,660 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:10,661 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,666 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:10,667 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:10,669 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:10,670 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:10,674 - library_manager.py:30 - INFO - Found 2 movies in library
# 2025-07-30 20:58:10,677 - supervisor.py:21 - INFO - Supervisor processing request
# 2025-07-30 20:58:13,117 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:13,122 - supervisor.py:32 - INFO - Supervisor routing to END
# ✅ Success (4.52s): Library scan completed. Found 2 movies.
# File types: .mkv: 2
# Sample movies:
# - DieHart2DieHarter2024
# -...

# %% [markdown]
# ## Enhanced Error Handling Examples
#
# The following cells demonstrate robust error handling patterns for different types of failures that might occur during testing.

# %%
# Basic test using the sync workflow agent (Jupyter-compatible)\nresult, thread_id = movie_workflow_agent.invoke(\"What movies are in my library?\")\nprint(f\"Response: {result['messages'][-1].content}\")

# %% [markdown]
# ## 2. Simple Graph Testing
#
# **Note**: The workflow is now fully synchronous and works seamlessly in Jupyter notebooks. Use the `invoke()` method as shown below.

# %%
# Enhanced individual tool testing with error handling and timing
def test_tool_safely(tool, query, tool_name):
    """Test a tool with comprehensive error handling"""
    print(f"🔧 Testing {tool_name} with query: '{query}'")
    start_time = time.time()
    
    try:
        result = tool._run(query)
        execution_time = time.time() - start_time
        print(f"✅ Success ({execution_time:.2f}s):")
        print(f"   Result: {str(result)[:200]}...")
        return result
    except ConnectionError as e:
        print(f"🌐 Network Error: {e}")
    except Exception as e:
        execution_time = time.time() - start_time
        print(f"❌ Error ({execution_time:.2f}s): {type(e).__name__}: {e}")
    print()

# Test movie retriever tool
test_tool_safely(movie_retriever_tool, "science fiction movies", "Movie Retriever Tool")

# Test with different query types
test_tool_safely(movie_retriever_tool, "action movies with Tom Cruise", "Movie Retriever Tool")
test_tool_safely(movie_retriever_tool, "romantic comedies", "Movie Retriever Tool")
# Out:
# 🔧 Testing Movie Retriever Tool with query: 'science fiction movies'
# 2025-07-30 20:58:14,569 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ✅ Success (1.89s):
#    Result: Found 5 movies matching 'science fiction movies':
#
# 1. Skyline (2010)
#    Director: Brothers Strause
#    Cast: Eric Balfour, Scottie Thompson, Donald Faison, David Zayas, Brittany Daniel, Neil Hopkins
#   ...
# 🔧 Testing Movie Retriever Tool with query: 'action movies with Tom Cruise'
# 2025-07-30 20:58:16,386 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ✅ Success (1.72s):
#    Result: Found 5 movies matching 'action movies with Tom Cruise':
#
# 1. Mission: Impossible – Ghost Protocol (2011)
#    Director: Brad Bird
#    Cast: Tom Cruise, Jeremy Renner, Simon Pegg, Paula Patton, Michael Ny...
# 🔧 Testing Movie Retriever Tool with query: 'romantic comedies'
# 2025-07-30 20:58:17,548 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ✅ Success (1.11s):
#    Result: Found 5 movies matching 'romantic comedies':
#
# 1. The Romantics (2010)
#    Director: Galt Niederhoffer
#    Cast: Katie Holmes, Josh Duhamel, Anna Paquin, Malin Åkerman, Adam Brody, Dianna Agron, Jeremy S...
# 'Found 5 movies matching \'romantic comedies\':\n\n1. The Romantics (2010)\n   Director: Galt Niederhoffer\n   Cast: Katie Holmes, Josh Duhamel, Anna Paquin, Malin Åkerman, Adam Brody, Dianna Agron, Jeremy Strong, Rebecca Lawrence, Candice Bergen, Elijah Wood\n   Genre: romantic comedy\n   Plot: A group of seven college friends reunite after six years for a wedding. Things go awry when the maid of honor, Laura, (Katie Holmes[3]) and the bride, Lila (Anna Paquin), clash over the groom, Tom (Josh Duhamel), with whom Laura was once romantically involved. As Laura, Lila, and Tom all try to decipher their emotions, the film explores all of the relationships of people in and around the circle of friends that met those years ago.\n\n2. Just Friends (2005)\n   Director: Roger Kumble\n   Cast: Ryan Reynolds, Amy Smart, Anna Faris, Chris Klein\n   Genre: romance\n   Plot: In 1995, Chris Brander (Ryan Reynolds) is an overweight high school student with a lisp, braces, and a "gentle giant" demeanor who secretly has a huge romantic crush on his classmate and best friend Jamie Palamino (Amy Smart). After confessing his feelings by writing them in Jamie\'s yearbook, he attends Jamie\'s graduation party. As he returns the yearbook to her, it is secretly swapped by her despicable ex-boyfriend, Tim (Ty Olsson), who reads the declaration aloud to everyone and humiliates Chris. Jamie doesn\'t reciprocate his romantic feelings; after they share a brief kiss on the cheek, Tim and the class burst in and humiliate Chris again. While Jamie admonishes them, an enraged Chris tearfully leaves the party, announcing that he would never return and vows to be more successful than e...\n\n3. They Came Together (2014)\n   Director: David Wain\n   Cast: Paul Rudd\nAmy Poehler\nCobie Smulders\nChristopher Meloni\n   Genre: comedy\n   Plot: When Joel (Rudd) and Molly (Poehler) meet, it\'s hate at first sight: his big Corporate Candy Company threatens to shut down her quirky indie candy shop. But amazingly (and predictably), they fall in love, until they break up and then must find their way back together.\n\n4. When in Rome (2010)\n   Director: Mark Steven Johnson\n   Cast: Kristen Bell, Josh Duhamel, Will Arnett, Jon Heder, Dax Shepard, Danny DeVito, Anjelica Huston\n   Genre: romantic comedy\n   Plot: Successful and single Beth (Kristen Bell), an art curator at the Guggenheim, is at a point in her life where love seems like a luxury she can\'t afford. Waiting for the "perfect" romance has embittered her. After flying to Rome to attend her younger sister Joan\'s (Alexis Dziena) impulsive wedding, she meets Nicholas Beamon (Josh Duhamel). He rescues her in a couple of difficult situations but they are both clumsy. Still, they hit it off.\nAs Beth comes to believe in love again, she sees Nick kissing another woman, who turns out to be the groom\'s (Luca Calvani) "crazy cousin." Slightly drunk and jealous at seeing Nick with another woman, she picks up coins (a poker chip, a rare coin, a penny, a trick quarter and a Euro) from the "fountain of love" (probably based on the Trevi Fountain). Joan ...\n\n5. Dan in Real Life (2007)\n   Director: Peter Hedges\n   Cast: Steve Carell, Juliette Binoche, Dane Cook, John Mahoney, Emily Blunt, Dianne Wiest\n   Genre: comedy-drama\n   Plot: Dan Burns is a newspaper advice columnist, a widower, and single-parent to his three girls, living in Northern New Jersey. The family takes a trip to the rambling, Rhode Island home of his parents for an annual family gathering. Also in attendance are Dan\'s sister and brother with their families and Dan\'s younger brother Mitch who is known for his carefree bachelor ways.\nThe morning after their arrival, Dan meets Marie in a bookshop. They share a muffin and a heart-felt chat, although Marie gently warns Dan that she has a boyfriend. Dan returns to his parents\' house and announces that he has \'met someone\'. Brother Mitch introduces his new girlfriend Annie. Lo and behold, Dan\'s Marie i ...

# %%
# Test library manager tool with enhanced error handling
test_tool_safely(library_manager_tool, "scan library", "Library Manager Tool")

# Test different library operations
test_tool_safely(library_manager_tool, "list movies", "Library Manager Tool")
test_tool_safely(library_manager_tool, "find action movies", "Library Manager Tool")
# Out:
# 2025-07-30 20:58:17,870 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,874 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:17,876 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,880 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:17,882 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,884 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:58:17,885 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,888 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,893 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,895 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,899 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:17,900 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,904 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:17,905 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,907 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:17,908 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,912 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,918 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,920 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,923 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:17,925 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,930 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:17,931 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,934 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:17,941 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,946 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,952 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,953 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,957 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:17,958 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,962 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:17,963 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,965 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:17,966 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,969 - library_manager.py:30 - INFO - Found 2 movies in library
# 2025-07-30 20:58:17,971 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,975 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:17,976 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,980 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:17,981 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:17,984 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:58:17,984 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,988 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,994 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:17,995 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:17,998 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:17,999 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,005 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:18,006 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,008 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:18,009 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,014 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,021 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,022 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,025 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,026 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,031 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,032 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,035 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,036 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,040 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,047 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,049 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,052 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,054 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,058 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,059 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,062 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,062 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 🔧 Testing Library Manager Tool with query: 'scan library'
# ✅ Success (0.10s):
#    Result: Library scan completed. Found 2 movies.
# File types: .mkv: 2
# Sample movies:
# - DieHart2DieHarter2024
# - Hardcore Henry 2015
# ...
# 🔧 Testing Library Manager Tool with query: 'list movies'
# 2025-07-30 20:58:18,067 - library_manager.py:30 - INFO - Found 2 movies in library
# 2025-07-30 20:58:18,069 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# ✅ Success (0.10s):
#    Result: Library scan completed. Found 2 movies.
# File types: .mkv: 2
# Sample movies:
# - DieHart2DieHarter2024
# - Hardcore Henry 2015
# ...
# 🔧 Testing Library Manager Tool with query: 'find action movies'
# 2025-07-30 20:58:18,072 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:18,073 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,078 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:18,079 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,082 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:58:18,083 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,088 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,092 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,095 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,099 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:18,100 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,104 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:18,106 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,108 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:18,109 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,113 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,117 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,120 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,124 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,125 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,128 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,129 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,135 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:18,136 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,140 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,145 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,146 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:18,149 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,150 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,154 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,155 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:18,158 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:18,159 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:18,162 - library_manager.py:30 - INFO - Found 2 movies in library
# ✅ Success (0.09s):
#    Result: Library scan completed. Found 2 movies.
# File types: .mkv: 2
# Sample movies:
# - DieHart2DieHarter2024
# - Hardcore Henry 2015
# ...
# 'Library scan completed. Found 2 movies.\nFile types: .mkv: 2\nSample movies:\n- DieHart2DieHarter2024\n- Hardcore Henry 2015\n'

# %%
# Test torrent tools with enhanced error handling
test_tool_safely(torrent_search_tool, "The Matrix 1999", "Torrent Search Tool")

# Test torrent download tool
test_tool_safely(torrent_download_tool, "check status", "Torrent Download Tool")

# Test different search queries
test_tool_safely(torrent_search_tool, "Inception 2010 1080p", "Torrent Search Tool")
test_tool_safely(torrent_search_tool, "Interstellar IMAX", "Torrent Search Tool")
# Out:
# 🔧 Testing Torrent Search Tool with query: 'The Matrix 1999'
# 2025-07-30 20:58:23,202 - error_handler.py:62 - ERROR - TorrentAPI error in api_call: 400 Client Error: Bad Request for url: http://192.168.1.205:15080/api/v2/search/results
# 2025-07-30 20:58:23,203 - error_handler.py:62 - ERROR - TorrentAPI error in search_torrents: 'NoneType' object has no attribute 'status_code'
# ✅ Success (5.03s):
#    Result: No torrents found for 'The Matrix 1999'...
# 🔧 Testing Torrent Download Tool with query: 'check status'
# ✅ Success (0.02s):
#    Result: Currently downloading 2 items:
# - TheAccountant2202 (downloading)
# - DeepCover2025 (downloading)
# ...
# 🔧 Testing Torrent Search Tool with query: 'Inception 2010 1080p'
# 2025-07-30 20:58:28,241 - error_handler.py:62 - ERROR - TorrentAPI error in api_call: 400 Client Error: Bad Request for url: http://192.168.1.205:15080/api/v2/search/results
# 2025-07-30 20:58:28,241 - error_handler.py:62 - ERROR - TorrentAPI error in search_torrents: 'NoneType' object has no attribute 'status_code'
# ✅ Success (5.02s):
#    Result: No torrents found for 'Inception 2010 1080p'...
# 🔧 Testing Torrent Search Tool with query: 'Interstellar IMAX'
# 2025-07-30 20:58:33,265 - error_handler.py:62 - ERROR - TorrentAPI error in api_call: 400 Client Error: Bad Request for url: http://192.168.1.205:15080/api/v2/search/results
# 2025-07-30 20:58:33,266 - error_handler.py:62 - ERROR - TorrentAPI error in search_torrents: 'NoneType' object has no attribute 'status_code'
# ✅ Success (5.02s):
#    Result: No torrents found for 'Interstellar IMAX'...
# "No torrents found for 'Interstellar IMAX'"

# %% [markdown]
# ## 3. Individual Agent Testing

# %%
# Scenario 1: Library Check with Performance Monitoring
print("=== Library Check with Performance Monitoring ===")
result, _ = perf_monitor.benchmark_query("What movies are available in my library?")
if result:
    print(f"Response: {result['messages'][-1].content[:200]}...")
print()
# Out:
# 2025-07-30 20:58:33,278 - supervisor.py:21 - INFO - Supervisor processing request
# === Library Check with Performance Monitoring ===
# 📊 Benchmarking: 'What movies are available in my library?' (1 iteration(s))
# --------------------------------------------------
# 2025-07-30 20:58:34,932 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:34,937 - supervisor.py:34 - INFO - Supervisor routing to: library_manager_agent
# 2025-07-30 20:58:34,940 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:34,944 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:34,945 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:34,950 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete
# 2025-07-30 20:58:34,951 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:34,953 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete
# 2025-07-30 20:58:34,954 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:34,958 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:34,963 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:34,965 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:34,969 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:34,970 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:34,974 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:34,975 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:34,978 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Die.Hart.2.Die.Harter.2024.1080p.AMZN.WEBRip.1400MB.DD5.1.x264-GalaxyRG[TGx]
# 2025-07-30 20:58:34,978 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:34,982 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:34,989 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:34,991 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:34,994 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:34,995 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:34,999 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:35,000 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:35,003 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hardcore Henry (2015) 720p BluRay x264 AC3 Soup
# 2025-07-30 20:58:35,004 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:35,008 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:35,013 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:35,014 - open.py:1163 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Create Response
# 2025-07-30 20:58:35,018 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:35,019 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:35,023 - open.py:1428 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Query Directory Request for directory elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:35,024 - open.py:1439 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Query Response
# 2025-07-30 20:58:35,026 - open.py:1485 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - sending SMB2 Close Request for file elements_main\torrent\incomplete\Hercules (1997) [1080p] [YTS.AG]
# 2025-07-30 20:58:35,027 - open.py:1496 - INFO - Session: dave, Tree Connect: \\192.168.1.205\daves - receiving SMB2 Close Response
# 2025-07-30 20:58:35,031 - library_manager.py:30 - INFO - Found 2 movies in library
# 2025-07-30 20:58:35,033 - supervisor.py:21 - INFO - Supervisor processing request
# 2025-07-30 20:58:36,490 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:36,496 - supervisor.py:32 - INFO - Supervisor routing to END
# 📈 Results:
#   Average time: 3.22s
#   Total time: 3.22s
#   Average memory delta: -29.1MB
#   Current memory usage: 87.8MB
# Response: Library scan completed. Found 2 movies.
# File types: .mkv: 2
# Sample movies:
# - DieHart2DieHarter2024
# - Hardcore Henry 2015
# ...

# %%
# Scenario 2: Movie Search with Error Handling
print("=== Movie Search with Enhanced Error Handling ===")
result, _ = safe_invoke("Find movies similar to The Matrix")
if result:
    print(f"Response: {result['messages'][-1].content[:200]}...")
print()
# Out:
# 2025-07-30 20:58:36,513 - supervisor.py:21 - INFO - Supervisor processing request
# === Movie Search with Enhanced Error Handling ===
# 🔄 Processing: 'Find movies similar to The Matrix'
# 2025-07-30 20:58:38,265 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:38,271 - supervisor.py:34 - INFO - Supervisor routing to: movie_details_retriever_agent
# 2025-07-30 20:58:42,636 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:45,669 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:47,348 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 20:58:48,494 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:55,561 - supervisor.py:21 - INFO - Supervisor processing request
# 2025-07-30 20:58:56,934 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:56,936 - supervisor.py:32 - INFO - Supervisor routing to END
# ✅ Success (20.43s): Agent stopped due to iteration limit or time limit....
# Response: Agent stopped due to iteration limit or time limit....

# %%
# Scenario 3: Movie Retrieval with Benchmarking
print("=== Movie Retrieval Benchmarking (3 iterations) ===")
result, _ = perf_monitor.benchmark_query("Tell me about sci-fi movies", iterations=3)
if result:
    print(f"Response: {result['messages'][-1].content[:200]}...")
print()
# Out:
# 2025-07-30 20:58:56,948 - supervisor.py:21 - INFO - Supervisor processing request
# === Movie Retrieval Benchmarking (3 iterations) ===
# 📊 Benchmarking: 'Tell me about sci-fi movies' (3 iteration(s))
# --------------------------------------------------
# 2025-07-30 20:58:58,119 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:58:58,123 - supervisor.py:34 - INFO - Supervisor routing to: movie_details_retriever_agent
# 2025-07-30 20:58:58,731 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:59:01,259 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 20:59:02,374 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:59:09,877 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:59:15,496 - supervisor.py:21 - INFO - Supervisor processing request
# 2025-07-30 20:59:18,092 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:59:18,096 - supervisor.py:34 - INFO - Supervisor routing to: movie_details_retriever_agent
# 2025-07-30 20:59:18,750 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-07-30 20:59:24,380 - _client.py:1025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 20:59:26,949 - _client.py:1025 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"

# %% [markdown]
# # Scenario 4: Multi-step conversation with enhanced monitoring
# print("=== Multi-step Conversation with Enhanced Monitoring ===")
#
# print("Step 1: Initial search")
# result1, thread_id = safe_invoke("Search for action movies")
# if result1:
#     print(f"✅ Step 1 Response: {result1['messages'][-1].content[:150]}...")
#     print()
#
#     print("Step 2: Follow-up query")
#     result2, _ = safe_invoke("Find similar movies to the first one", thread_id)
#     if result2:
#         print(f"✅ Step 2 Response: {result2['messages'][-1].content[:150]}...")
#         print()
#
#         print("Step 3: Detailed information")
#         result3, _ = safe_invoke("Get more details about the most interesting one", thread_id)
#         if result3:
#             print(f"✅ Step 3 Response: {result3['messages'][-1].content[:150]}...")
#         else:
#             print("❌ Step 3 failed")
#     else:
#         print("❌ Step 2 failed")
# else:
#     print("❌ Step 1 failed")
#
# print(f"🧵 Thread ID used: {thread_id}")
# print("=" * 50)

# %%
# Scenario 1: Library Check\nprint(\"=== Library Check ===\")\nresult, _ = movie_workflow_agent.invoke(\"What movies are available in my library?\")\nprint(result['messages'][-1].content)\nprint()

# %%
# Enhanced helper functions for debugging and analysis
def print_graph_state(result, detailed=False):
    """Enhanced graph state analysis with detailed information"""
    print("=== Enhanced Graph State Analysis ===")
    
    if not result or 'messages' not in result:
        print("❌ No valid result or messages found")
        return
    
    messages = result.get('messages', [])
    print(f"📨 Messages count: {len(messages)}")
    print(f"⏱️  Last message timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print()
    
    for i, msg in enumerate(messages):
        msg_type = getattr(msg, 'type', 'unknown')
        msg_name = getattr(msg, 'name', 'no-name')
        content_preview = str(msg.content)[:100] if hasattr(msg, 'content') else 'no-content'
        
        print(f"Message {i+1} ({msg_type}):")
        print(f"  Name: {msg_name}")
        print(f"  Content: {content_preview}...")
        
        if detailed and hasattr(msg, 'additional_kwargs'):
            print(f"  Additional: {msg.additional_kwargs}")
        print()

def analyze_conversation_flow(result):
    """Analyze the conversation flow and agent interactions"""
    print("🔄 Conversation Flow Analysis")
    print("-" * 40)
    
    if not result or 'messages' not in result:
        print("❌ No valid conversation data")
        return
    
    messages = result.get('messages', [])
    agents_involved = set()
    message_types = {}
    
    for msg in messages:
        msg_type = getattr(msg, 'type', 'unknown')
        msg_name = getattr(msg, 'name', 'unnamed')
        
        agents_involved.add(msg_name)
        
        if msg_type not in message_types:
            message_types[msg_type] = 0
        message_types[msg_type] += 1
    
    print(f"🤖 Agents involved: {', '.join(agents_involved)}")
    print(f"📊 Message types: {dict(message_types)}")
    print(f"🔗 Total interaction steps: {len(messages)}")
    print()

# Test the enhanced helpers with a sample query
print("Testing enhanced debugging helpers...")
test_result, test_thread = safe_invoke("Tell me about a random movie")

if test_result:
    print_graph_state(test_result, detailed=True)
    analyze_conversation_flow(test_result)

# %%
# Enhanced agent routing analysis with performance monitoring
def test_agent_routing_enhanced(query):
    """Enhanced agent routing test with detailed analysis"""
    print(f"🎯 Testing routing for: '{query}'")
    print("-" * 60)
    
    start_time = time.time()
    result, thread_id = safe_invoke(query)
    total_time = time.time() - start_time
    
    if not result:
        print("❌ Query failed")
        return
    
    # Analyze routing
    messages = result.get('messages', [])
    agents_used = []
    
    for msg in messages:
        if hasattr(msg, 'name') and msg.name and msg.name != 'unnamed':
            agents_used.append(msg.name)
    
    unique_agents = list(set(agents_used))
    
    print(f"⚡ Total execution time: {total_time:.2f}s")
    print(f"🤖 Agents involved: {unique_agents if unique_agents else ['supervisor']}")
    print(f"🔄 Agent switches: {len(agents_used)}")
    print(f"📝 Final response length: {len(messages[-1].content) if messages else 0} chars")
    print(f"💬 Total messages: {len(messages)}")
    print()

# Comprehensive routing performance analysis
print("🚀 Comprehensive Agent Routing Performance Analysis")
print("=" * 70)

test_queries = [
    "What movies are in my library?",  # Library agent
    "Find movies about space exploration",  # Movie retriever agent
    "Download The Matrix",  # Torrent download agent
    "Search for torrents of Inception",  # Torrent search agent
    "Tell me about Christopher Nolan movies",  # Movie retriever agent
    "What's the status of my downloads?",  # Torrent download agent
    "Scan my movie library for new files",  # Library agent
    "Find action movies similar to John Wick"  # Movie retriever agent
]

for i, query in enumerate(test_queries, 1):
    print(f"Test {i}/{len(test_queries)}:")
    test_agent_routing_enhanced(query)

# Use performance monitor for overall analysis
print("📊 Overall Routing Performance Analysis:")
perf_monitor.analyze_routing_performance(test_queries[:4])  # Test subset to avoid long execution

# %%
def run_comprehensive_test_suite():
    """Run a comprehensive test suite for the Turtle App Graph"""
    print("🚀 Running Comprehensive Turtle App Test Suite")
    print("=" * 60)
    print(f"⏰ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print()
    
    test_results = {
        'total_tests': 0,
        'passed': 0,
        'failed': 0,
        'errors': []
    }
    
    # Test categories
    test_categories = [
        {
            'name': 'Graph Functionality',
            'tests': [
                "What movies are in my library?",
                "Tell me about sci-fi movies",
                "Find movies similar to The Matrix"
            ]
        },
        {
            'name': 'Agent Routing',
            'tests': [
                "Scan my movie library",
                "Search for Christopher Nolan movies",
                "Check torrent download status"
            ]
        },
        {
            'name': 'Thread Persistence',
            'tests': [
                ("Search for action movies", "Find similar movies to those"),
                ("Tell me about horror movies", "Which one would you recommend?")
            ]
        }
    ]
    
    suite_start_time = time.time()
    
    for category in test_categories:
        print(f"📋 Testing Category: {category['name']}")
        print("-" * 40)
        
        for test in category['tests']:
            test_results['total_tests'] += 1
            
            if isinstance(test, tuple):
                # Thread persistence test
                query1, query2 = test
                print(f"🧵 Thread test: '{query1}' → '{query2}'")
                
                try:
                    result1, thread_id = safe_invoke(query1)
                    if result1:
                        result2, _ = safe_invoke(query2, thread_id)
                        if result2:
                            print("✅ Thread persistence test passed")
                            test_results['passed'] += 1
                        else:
                            print("❌ Second query in thread failed")
                            test_results['failed'] += 1
                    else:
                        print("❌ First query in thread failed")
                        test_results['failed'] += 1
                except Exception as e:
                    print(f"❌ Thread test error: {e}")
                    test_results['failed'] += 1
                    test_results['errors'].append(str(e))
            else:
                # Regular test
                print(f"🔍 Testing: '{test}'")
                try:
                    result, _ = safe_invoke(test)
                    if result and 'messages' in result and result['messages']:
                        print("✅ Test passed")
                        test_results['passed'] += 1
                    else:
                        print("❌ Test failed - no valid response")
                        test_results['failed'] += 1
                except Exception as e:
                    print(f"❌ Test error: {e}")
                    test_results['failed'] += 1
                    test_results['errors'].append(str(e))
            print()
    
    suite_duration = time.time() - suite_start_time
    
    # Final results
    print("📊 Comprehensive Test Suite Results")
    print("=" * 60)
    print(f"⏱️  Total execution time: {suite_duration:.2f} seconds")
    print(f"📈 Tests run: {test_results['total_tests']}")
    print(f"✅ Passed: {test_results['passed']}")
    print(f"❌ Failed: {test_results['failed']}")
    print(f"📊 Success rate: {(test_results['passed'] / test_results['total_tests'] * 100):.1f}%")
    
    if test_results['errors']:
        print(f"\n🚨 Errors encountered:")
        for i, error in enumerate(test_results['errors'][:3], 1):  # Show first 3 errors
            print(f"  {i}. {error}")
    
    # System performance summary
    print(f"\n💻 Final System Status:")
    perf_monitor.get_system_info()
    
    print(f"\n🏁 Test suite completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    
    return test_results

# Run the comprehensive test suite
if __name__ == "__main__" or True:  # Enable for Jupyter execution
    comprehensive_results = run_comprehensive_test_suite()

# %% [markdown]
# ## Comprehensive Test Suite
#
# Run a complete test suite to validate all components and measure overall system performance.

# %%
# Scenario 4: Multi-step conversation\nprint(\"=== Multi-step Conversation ===\")\nresult1, thread_id = movie_workflow_agent.invoke(\"Search for action movies\")\nprint(f\"Step 1: {result1['messages'][-1].content}\")\nprint()\n\nresult2, _ = movie_workflow_agent.invoke(\"Find similar movies to the first one\", thread_id)\nprint(f\"Step 2: {result2['messages'][-1].content}\")\nprint()\n\nresult3, _ = movie_workflow_agent.invoke(\"Get more details about the most interesting one\", thread_id)\nprint(f\"Step 3: {result3['messages'][-1].content}\")

# %% [markdown]
# ## 5. Debug and Inspection Helpers

# %%
# Helper function to pretty print graph state\ndef print_graph_state(result):\n    \"\"\"Pretty print the graph state from a workflow result\"\"\"\n    print(\"=== Graph State ===\")\n    print(f\"Messages count: {len(result.get('messages', []))}\")\n    \n    for i, msg in enumerate(result.get('messages', [])):\n        print(f\"Message {i+1} ({msg.type}): {msg.content[:100]}...\")\n    print()\n\n# Test the helper\nresult, _ = movie_workflow_agent.invoke(\"Quick test message\")\nprint_graph_state(result)

# %%
# Helper to test agent routing\ndef test_agent_routing(query):\n    \"\"\"Test which agent the supervisor routes a query to\"\"\"\n    print(f\"Testing routing for: '{query}'\")\n    result, thread_id = movie_workflow_agent.invoke(query)\n    \n    # Look at the messages to understand routing\n    messages = result.get('messages', [])\n    for msg in messages:\n        if hasattr(msg, 'name') and msg.name:\n            print(f\"Routed to agent: {msg.name}\")\n    \n    print(f\"Final response: {messages[-1].content[:200]}...\")\n    print()\n\n# Test different routing scenarios\ntest_queries = [\n    \"What movies are in my library?\",\n    \"Find movies about space exploration\",\n    \"Download The Matrix\",\n    \"Search for torrents of Inception\"\n]\n\nfor query in test_queries:\n    test_agent_routing(query)
